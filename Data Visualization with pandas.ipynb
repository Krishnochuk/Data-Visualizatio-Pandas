# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from numpy.random import randint,randn,uniform, sample

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2019-06-07',periods=1000),columns=['values'])
ts=pd.Series(randn(1000),index=pd.date_range('2019-06-07',periods=1000))
df.head()
# Out:
#               values
# 2019-06-07  0.938447
# 2019-06-08  0.110873
# 2019-06-09 -0.319371
# 2019-06-10 -0.959002
# 2019-06-11  0.658520

# %%
df['values']=df['values'].cumsum()
df.head()
# Out:
#               values
# 2019-06-07  0.938447
# 2019-06-08  1.049321
# 2019-06-09  0.729950
# 2019-06-10 -0.229052
# 2019-06-11  0.429468

# %%
ts.plot()  # here we are using pandas for plotting

# %%
df.plot(figsize=(5,5))

# %%
df.plot(subplots=True,sharex=False,layout=(2,3),figsize=(16,8)) #layout(rows,columns),
plt.tight_layout()

# %%
plt.plot(ts)  #here we are using matplotlib for plotting

# %%
iris=sns.load_dataset('iris')  # reading file from seaborne
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#by default it will take a line graph
ax=iris.plot(figsize=(15,5),title='iris Dataset',subplots=True)
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-6191a8d10ccc> in <module>
#       1 #by default it will take a line graph
#       2 ax=iris.plot(figsize=(15,5),title='iris Dataset',subplots=True)
# ----> 3 ax.set_xlabel('x-axis')
#       4 ax.set_ylabel('y-axis')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_xlabel'

# %%
iris.iloc[0].plot()

# %%
iris.iloc[0].plot(kind='bar')

# %%
iris.iloc[0].plot.bar()  # other way of representation

# %%
titanic=pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['Pclass'].plot(kind='bar')

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df.head(4)
# Out:
#           a         b         c         d
# 0  0.269831 -0.367707  0.313200 -2.651834
# 1  0.017173 -0.099886  0.418188 -0.439576
# 2  1.006952 -0.412901  1.999869  0.142355
# 3 -0.625025 -0.270564  0.287089 -1.025055

# %%
df.plot(kind='bar')  #by default it gives vertical graph

# %%
df.plot(kind='barh')

# %%
iris['sepal_length'].plot(kind='hist')   # iris.plot.hist()  will alse works

# %%
iris.plot(kind='hist',stacked=False,bins=10)  #stack prevents from overlaping of data
                                                #

# %%
iris.plot(kind='hist',stacked=True,bins=10,orientation='horizontal')

# %%
iris['sepal_width'].diff().head()
# Out:
# 0    NaN
# 1   -0.5
# 2    0.2
# 3   -0.1
# 4    0.5
# Name: sepal_width, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked=True,bins=50)

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked=True,bins=50,color='r',alpha=.8) # alpha denotes the intensity of colour

# %%
iris.plot(kind='scatter',x='sepal_length',y='petal_length')  # in scatter plot we need to give x and y axis

# %%
iris.plot(kind='scatter',x='sepal_length',y='petal_length',c='sepal_width',s=50) # s represents size of dots

# %%
a=iris.iloc[0]
a
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
a.plot(kind='pie',figsize=(5,5))

# %%
d=iris.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot(kind='pie',subplots=True,figsize=(20,20),fontsize=20)
plt.show()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(iris,figsize=(10,10),color='r',diagonal='kde')#scatter_matrix is used to find the relationship beween all the
#column
plt.show()

# %%
iris.plot(kind='kde')  #kde is made from the histogram
